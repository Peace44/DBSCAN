# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('../OUTPUTS/random_points_clusters.csv')  # replace 'path_to_your_file.csv' with the actual file path

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Get unique clusters
clusters = sorted(df['cluster'].unique())

# Color map
colors = plt.cm.jet(np.linspace(0, 1, len(clusters))) if len(clusters) > 1 else []

for i, cluster in enumerate(clusters):
    # Filter points belonging to the current cluster
    points = df[df['cluster'] == cluster]
    
    if cluster == -1:
        color = 'black'
    else:
        color_index = i-1 if -1 in clusters else i
        color = colors[color_index]
    
    # Plot points with the cluster-specific color
    ax.scatter(points['x'], points['y'], points['z'], s=20, color=color, label=f'Cluster {cluster}')

# Labeling
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.title('3D Cluster Plot')
plt.show()

# %%
import pandas as pd
import h5py

input_file = "../../random_points.csv"
output_file = "abc.h5"

df = pd.read_csv(input_file)
df.to_hdf(output_file, key="DATA", mode='w')
print(pd.read_hdf(output_file, key="DATA"))
# Out:
#                x          y         z  cluster
# 0      44.850488 -19.852902 -0.311067       21
# 1      53.177221  87.115457  1.449126        4
# 2     -72.593789  86.669793  0.399561       23
# 3     -54.659540  10.804856  1.747731       45
# 4      53.473640 -74.404255  3.334681       18
# ...          ...        ...       ...      ...
# 99995 -53.636085  85.840876  0.078509       16
# 99996  83.399580 -53.607982  0.970002       46
# 99997 -52.452268 -63.684663 -2.561725       41
# 99998   9.647802 -66.549863 -1.661242       32
# 99999 -63.325534 -62.667880  0.284053       10
#
# [100000 rows x 4 columns]
